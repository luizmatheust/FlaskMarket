# %% [markdown]
# <a href="https://colab.research.google.com/github/luizmatheust/FlaskMarket/blob/master/Aula_01_09_06_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relatório da Agência - Luiz Matheus
# **Status: em construção**

# %%
print("Sistema Iniciado")
# Out:
# Sistema Iniciado

# %%
capital = 1000
taxa_mensal = 0.02
meses = 6
juros = capital * taxa_mensal * meses
print("O valor do juros é", juros)
montante = capital + juros
print("O Valor do Montante é", montante)
# Out:
# O valor do juros é 120.0
# O Valor do Montante é 1120.0
